# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import datetime
import math
#jupyter notebook --notebook-dir=C:\xampp\htdocs\
import skrf as rf

# %%
port1_MOS1 = rf.Network('port1_MOS1.s1p')
port2_MOS2 = rf.Network('port2_MOS2.s1p')
port3_MOS3 = rf.Network('port3_MOS3.s1p')
port4_MOS4 = rf.Network('port4_MOS4.s1p')
port5_MOS5 = rf.Network('port5_MOS5.s1p')
port6_MOS6 = rf.Network('port6_MOS6.s1p')

port1_MOS6 = rf.Network('port1_MOS6.s1p')
port2_MOS1 = rf.Network('port2_MOS1.s1p')
port3_MOS2 = rf.Network('port3_MOS2.s1p')
port4_MOS3 = rf.Network('port4_MOS3.s1p')
port5_MOS4 = rf.Network('port5_MOS4.s1p')
port6_MOS5 = rf.Network('port6_MOS5.s1p')

port1_MOS5 = rf.Network('port1_MOS5.s1p')
port2_MOS6 = rf.Network('port2_MOS6.s1p')
port3_MOS1 = rf.Network('port3_MOS1.s1p')
port4_MOS2 = rf.Network('port4_MOS2.s1p')
port5_MOS3 = rf.Network('port5_MOS3.s1p')
port6_MOS4 = rf.Network('port6_MOS4.s1p')

port1_MOS4 = rf.Network('port1_MOS4.s1p')
port2_MOS5 = rf.Network('port2_MOS5.s1p')
port3_MOS6 = rf.Network('port3_MOS6.s1p')
port4_MOS1 = rf.Network('port4_MOS1.s1p')
port5_MOS2 = rf.Network('port5_MOS2.s1p')
port6_MOS3 = rf.Network('port6_MOS3.s1p')

port1_MOS3 = rf.Network('port1_MOS3.s1p')
port2_MOS4 = rf.Network('port2_MOS4.s1p')
port3_MOS5 = rf.Network('port3_MOS5.s1p')
port4_MOS6 = rf.Network('port4_MOS6.s1p')
port5_MOS1 = rf.Network('port5_MOS1.s1p')
port6_MOS2 = rf.Network('port6_MOS2.s1p')

port1_MOS2 = rf.Network('port1_MOS2.s1p')
port2_MOS3 = rf.Network('port2_MOS3.s1p')
port3_MOS4 = rf.Network('port3_MOS4.s1p')
port4_MOS5 = rf.Network('port4_MOS5.s1p')
port5_MOS6 = rf.Network('port5_MOS6.s1p')
port6_MOS1 = rf.Network('port6_MOS1.s1p')


N = len(port1_MOS1.s11.s_deg_unwrap)

# %%
port1_MOS1_phase = np.array([])
for index in range(N):
    port1_MOS1_phase = np.append(port1_MOS1_phase,port1_MOS1.s11.s_deg_unwrap[index][0][0])

port2_MOS2_phase = np.array([])
for index in range(N):
    port2_MOS2_phase = np.append(port2_MOS2_phase,port2_MOS2.s11.s_deg_unwrap[index][0][0])

port3_MOS3_phase = np.array([])
for index in range(N):
    port3_MOS3_phase = np.append(port3_MOS3_phase,port3_MOS3.s11.s_deg_unwrap[index][0][0])

port4_MOS4_phase = np.array([])
for index in range(N):
    port4_MOS4_phase = np.append(port4_MOS4_phase,port4_MOS4.s11.s_deg_unwrap[index][0][0])

port5_MOS5_phase = np.array([])
for index in range(N):
    port5_MOS5_phase = np.append(port5_MOS5_phase,port5_MOS5.s11.s_deg_unwrap[index][0][0])

port6_MOS6_phase = np.array([])
for index in range(N):
    port6_MOS6_phase = np.append(port6_MOS6_phase,port6_MOS6.s11.s_deg_unwrap[index][0][0])

# %%
port1_MOS6_phase = np.array([])
for index in range(N):
    port1_MOS6_phase = np.append(port1_MOS6_phase,port1_MOS6.s11.s_deg_unwrap[index][0][0])

port2_MOS1_phase = np.array([])
for index in range(N):
    port2_MOS1_phase = np.append(port2_MOS1_phase,port2_MOS1.s11.s_deg_unwrap[index][0][0])

port3_MOS2_phase = np.array([])
for index in range(N):
    port3_MOS2_phase = np.append(port3_MOS2_phase,port3_MOS2.s11.s_deg_unwrap[index][0][0])

port4_MOS3_phase = np.array([])
for index in range(N):
    port4_MOS3_phase = np.append(port4_MOS3_phase,port4_MOS3.s11.s_deg_unwrap[index][0][0])

port5_MOS4_phase = np.array([])
for index in range(N):
    port5_MOS4_phase = np.append(port5_MOS4_phase,port5_MOS4.s11.s_deg_unwrap[index][0][0])

port6_MOS5_phase = np.array([])
for index in range(N):
    port6_MOS5_phase = np.append(port6_MOS5_phase,port6_MOS5.s11.s_deg_unwrap[index][0][0])

# %%
port1_MOS5_phase = np.array([])
for index in range(N):
    port1_MOS5_phase = np.append(port1_MOS5_phase,port1_MOS5.s11.s_deg_unwrap[index][0][0])

port2_MOS6_phase = np.array([])
for index in range(N):
    port2_MOS6_phase = np.append(port2_MOS6_phase,port2_MOS6.s11.s_deg_unwrap[index][0][0])

port3_MOS1_phase = np.array([])
for index in range(N):
    port3_MOS1_phase = np.append(port3_MOS1_phase,port3_MOS1.s11.s_deg_unwrap[index][0][0])

port4_MOS2_phase = np.array([])
for index in range(N):
    port4_MOS2_phase = np.append(port4_MOS2_phase,port4_MOS2.s11.s_deg_unwrap[index][0][0])

port5_MOS3_phase = np.array([])
for index in range(N):
    port5_MOS3_phase = np.append(port5_MOS3_phase,port5_MOS3.s11.s_deg_unwrap[index][0][0])

port6_MOS4_phase = np.array([])
for index in range(N):
    port6_MOS4_phase = np.append(port6_MOS4_phase,port6_MOS4.s11.s_deg_unwrap[index][0][0])

# %%
port1_MOS4_phase = np.array([])
for index in range(N):
    port1_MOS4_phase = np.append(port1_MOS4_phase,port1_MOS4.s11.s_deg_unwrap[index][0][0])

port2_MOS5_phase = np.array([])
for index in range(N):
    port2_MOS5_phase = np.append(port2_MOS5_phase,port2_MOS5.s11.s_deg_unwrap[index][0][0])

port3_MOS6_phase = np.array([])
for index in range(N):
    port3_MOS6_phase = np.append(port3_MOS6_phase,port3_MOS6.s11.s_deg_unwrap[index][0][0])

port4_MOS1_phase = np.array([])
for index in range(N):
    port4_MOS1_phase = np.append(port4_MOS1_phase,port4_MOS1.s11.s_deg_unwrap[index][0][0])

port5_MOS2_phase = np.array([])
for index in range(N):
    port5_MOS2_phase = np.append(port5_MOS2_phase,port5_MOS2.s11.s_deg_unwrap[index][0][0])

port6_MOS3_phase = np.array([])
for index in range(N):
    port6_MOS3_phase = np.append(port6_MOS3_phase,port6_MOS3.s11.s_deg_unwrap[index][0][0])

# %%
port1_MOS3_phase = np.array([])
for index in range(N):
    port1_MOS3_phase = np.append(port1_MOS3_phase,port1_MOS3.s11.s_deg_unwrap[index][0][0])

port2_MOS4_phase = np.array([])
for index in range(N):
    port2_MOS4_phase = np.append(port2_MOS4_phase,port2_MOS4.s11.s_deg_unwrap[index][0][0])

port3_MOS5_phase = np.array([])
for index in range(N):
    port3_MOS5_phase = np.append(port3_MOS5_phase,port3_MOS5.s11.s_deg_unwrap[index][0][0])

port4_MOS6_phase = np.array([])
for index in range(N):
    port4_MOS6_phase = np.append(port4_MOS6_phase,port4_MOS6.s11.s_deg_unwrap[index][0][0])

port5_MOS1_phase = np.array([])
for index in range(N):
    port5_MOS1_phase = np.append(port5_MOS1_phase,port5_MOS1.s11.s_deg_unwrap[index][0][0])

port6_MOS2_phase = np.array([])
for index in range(N):
    port6_MOS2_phase = np.append(port6_MOS2_phase,port6_MOS2.s11.s_deg_unwrap[index][0][0])

# %%
port1_MOS2_phase = np.array([])
for index in range(N):
    port1_MOS2_phase = np.append(port1_MOS2_phase,port1_MOS2.s11.s_deg_unwrap[index][0][0])

port2_MOS3_phase = np.array([])
for index in range(N):
    port2_MOS3_phase = np.append(port2_MOS3_phase,port2_MOS3.s11.s_deg_unwrap[index][0][0])

port3_MOS4_phase = np.array([])
for index in range(N):
    port3_MOS4_phase = np.append(port3_MOS4_phase,port3_MOS4.s11.s_deg_unwrap[index][0][0])

port4_MOS5_phase = np.array([])
for index in range(N):
    port4_MOS5_phase = np.append(port4_MOS5_phase,port4_MOS5.s11.s_deg_unwrap[index][0][0])

port5_MOS6_phase = np.array([])
for index in range(N):
    port5_MOS6_phase = np.append(port5_MOS6_phase,port5_MOS6.s11.s_deg_unwrap[index][0][0])

port6_MOS1_phase = np.array([])
for index in range(N):
    port6_MOS1_phase = np.append(port6_MOS1_phase,port6_MOS1.s11.s_deg_unwrap[index][0][0])

# %%
plt.plot(port1_MOS1.f/1e9,port1_MOS1_phase - port1_MOS1_phase,"-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS2_phase - port1_MOS1_phase,"-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS3_phase - port1_MOS1_phase,"-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS4_phase - port1_MOS1_phase,"-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS5_phase - port1_MOS1_phase,"-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS6_phase - port1_MOS1_phase,"-",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS6_phase - port2_MOS1_phase,"--",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS1_phase - port2_MOS1_phase,"--",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS2_phase - port2_MOS1_phase,"--",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS3_phase - port2_MOS1_phase,"--",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS4_phase - port2_MOS1_phase,"--",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS5_phase - port2_MOS1_phase,"--",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS5_phase - port3_MOS1_phase,"-.",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS6_phase - port3_MOS1_phase,"-.",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS1_phase - port3_MOS1_phase,"-.",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS2_phase - port3_MOS1_phase,"-.",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS3_phase - port3_MOS1_phase,"-.",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS4_phase - port3_MOS1_phase,"-.",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS4_phase - port4_MOS1_phase,":",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS5_phase - port4_MOS1_phase,":",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS6_phase - port4_MOS1_phase,":",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS1_phase - port4_MOS1_phase,":",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS2_phase - port4_MOS1_phase,":",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS3_phase - port4_MOS1_phase,":",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS3_phase - port5_MOS1_phase,"-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS4_phase - port5_MOS1_phase,"-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS5_phase - port5_MOS1_phase,"-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS6_phase - port5_MOS1_phase,"-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS1_phase - port5_MOS1_phase,"-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS2_phase - port5_MOS1_phase,"-",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS2_phase - port6_MOS1_phase,"-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS3_phase - port6_MOS1_phase,"-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS4_phase - port6_MOS1_phase,"-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS5_phase - port6_MOS1_phase,"-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS6_phase - port6_MOS1_phase,"-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS1_phase - port6_MOS1_phase,"-",color="purple")

plt.grid()
plt.xlabel('Frequency [GHz]')
plt.ylabel('$S_{11}$ Phase difference From Flat Short [deg]')
plt.xlim((0,10))
plt.ylim((-1000,10))
#plt.legend(['Port 1 A','Port 2 A','Port 3 A','Port 4 A','Port 5 A','Port 6 A','Port 1 B','Port 2 B','Port 3 B','Port 4 B','Port 5 B','Port 6 B'],loc=3)
# Out:
# (-1000.0, 10.0)

# %%
plt.plot(port1_MOS1.f/1e9,port1_MOS1_phase - port1_MOS1_phase,"-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS2_phase - port1_MOS1_phase,"-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS3_phase - port1_MOS1_phase,"-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS4_phase - port1_MOS1_phase,"-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS5_phase - port1_MOS1_phase,"-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS6_phase - port1_MOS1_phase,"-",color="purple")


plt.plot(port1_MOS1.f/1e9,port1_MOS6_phase - port2_MOS1_phase,"--",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS1_phase - port2_MOS1_phase,"--",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS2_phase - port2_MOS1_phase,"--",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS3_phase - port2_MOS1_phase,"--",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS4_phase - port2_MOS1_phase,"--",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS5_phase - port2_MOS1_phase,"--",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS5_phase - port3_MOS1_phase,"-.",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS6_phase - port3_MOS1_phase,"-.",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS1_phase - port3_MOS1_phase,"-.",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS2_phase - port3_MOS1_phase,"-.",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS3_phase - port3_MOS1_phase,"-.",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS4_phase - port3_MOS1_phase,"-.",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS4_phase - port4_MOS1_phase,":",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS5_phase - port4_MOS1_phase,":",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS6_phase - port4_MOS1_phase,":",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS1_phase - port4_MOS1_phase,":",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS2_phase - port4_MOS1_phase,":",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS3_phase - port4_MOS1_phase,":",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS3_phase - port5_MOS1_phase,"-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS4_phase - port5_MOS1_phase,"-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS5_phase - port5_MOS1_phase,"-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS6_phase - port5_MOS1_phase,"-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS1_phase - port5_MOS1_phase,"-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS2_phase - port5_MOS1_phase,"-",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS2_phase - port6_MOS1_phase,"-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS3_phase - port6_MOS1_phase,"-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS4_phase - port6_MOS1_phase,"-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS5_phase - port6_MOS1_phase,"-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS6_phase - port6_MOS1_phase,"-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS1_phase - port6_MOS1_phase,"-",color="purple")

plt.grid()
plt.xlabel('Frequency [GHz]')
plt.ylabel('$S_{11}$ Phase difference From Flat Short [deg]')
plt.xlim((0,1))
plt.ylim((-220,10))
#plt.legend(['Port 1 A','Port 2 A','Port 3 A','Port 4 A','Port 5 A','Port 6 A','Port 1 B','Port 2 B','Port 3 B','Port 4 B','Port 5 B','Port 6 B','Port 1 C','Port 2 C','Port 3 C','Port 4 C','Port 5 C','Port 6 C'],loc=3)
# Out:
# (-220.0, 10.0)

# %%
plt.plot(port1_MOS1.f/1e9,port1_MOS1_phase - port1_MOS1_phase,"+-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS2_phase - port1_MOS1_phase,"+-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS3_phase - port1_MOS1_phase,"+-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS4_phase - port1_MOS1_phase,"+-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS5_phase - port1_MOS1_phase,"+-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS6_phase - port1_MOS1_phase,"+-",color="purple")


plt.plot(port1_MOS1.f/1e9,port1_MOS6_phase - port2_MOS1_phase,"+-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS1_phase - port2_MOS1_phase,"+-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS2_phase - port2_MOS1_phase,"+-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS3_phase - port2_MOS1_phase,"+-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS4_phase - port2_MOS1_phase,"+-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS5_phase - port2_MOS1_phase,"+-",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS5_phase - port3_MOS1_phase,"+-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS6_phase - port3_MOS1_phase,"+-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS1_phase - port3_MOS1_phase,"+-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS2_phase - port3_MOS1_phase,"+-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS3_phase - port3_MOS1_phase,"+-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS4_phase - port3_MOS1_phase,"+-",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS4_phase - port4_MOS1_phase,"+-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS5_phase - port4_MOS1_phase,"+-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS6_phase - port4_MOS1_phase,"+-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS1_phase - port4_MOS1_phase,"+-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS2_phase - port4_MOS1_phase,"+-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS3_phase - port4_MOS1_phase,"+-",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS3_phase - port5_MOS1_phase,"+-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS4_phase - port5_MOS1_phase,"+-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS5_phase - port5_MOS1_phase,"+-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS6_phase - port5_MOS1_phase,"+-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS1_phase - port5_MOS1_phase,"+-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS2_phase - port5_MOS1_phase,"+-",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS2_phase - port6_MOS1_phase,"+-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS3_phase - port6_MOS1_phase,"+-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS4_phase - port6_MOS1_phase,"+-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS5_phase - port6_MOS1_phase,"+-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS6_phase - port6_MOS1_phase,"+-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS1_phase - port6_MOS1_phase,"+-",color="purple")

plt.grid()
plt.xlabel('Frequency [GHz]')
plt.ylabel('$S_{11}$ Phase difference From Flat Short [deg]')
plt.xlim((0.1,0.11))
plt.ylim((-10,1))
#plt.legend(['Port 1 A','Port 2 A','Port 3 A','Port 4 A','Port 5 A','Port 6 A','Port 1 B','Port 2 B','Port 3 B','Port 4 B','Port 5 B','Port 6 B','Port 1 C','Port 2 C','Port 3 C','Port 4 C','Port 5 C','Port 6 C'],loc=3)
# Out:
# (-10.0, 1.0)

# %%
plt.plot(port1_MOS1.f/1e9,port1_MOS1_phase - port1_MOS1_phase,"-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS2_phase - port1_MOS1_phase,"-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS3_phase - port1_MOS1_phase,"-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS4_phase - port1_MOS1_phase,"-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS5_phase - port1_MOS1_phase,"-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS6_phase - port1_MOS1_phase,"-",color="purple")


plt.plot(port1_MOS1.f/1e9,port1_MOS6_phase - port2_MOS1_phase,"--",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS1_phase - port2_MOS1_phase,"--",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS2_phase - port2_MOS1_phase,"--",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS3_phase - port2_MOS1_phase,"--",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS4_phase - port2_MOS1_phase,"--",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS5_phase - port2_MOS1_phase,"--",color="purple")

plt.plot(port1_MOS1.f/1e9,port1_MOS5_phase - port3_MOS1_phase,"-.",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS6_phase - port3_MOS1_phase,"-.",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS1_phase - port3_MOS1_phase,"-.",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS2_phase - port3_MOS1_phase,"-.",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS3_phase - port3_MOS1_phase,"-.",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS4_phase - port3_MOS1_phase,"-.",color="purple")


plt.grid()
plt.xlabel('Frequency [GHz]')
plt.ylabel('$S_{11}$ Phase difference From Flat Short [deg]')
plt.xlim((3,3.5))
plt.ylim((-300,10))
plt.legend(['Port 1 A','Port 2 A','Port 3 A','Port 4 A','Port 5 A','Port 6 A','Port 1 B','Port 2 B','Port 3 B','Port 4 B','Port 5 B','Port 6 B'],loc=3)

# %%
plt.plot(port1_MOS1.f/1e9,port1_MOS1_phase - port1_MOS1_phase,"-",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS2_phase - port1_MOS1_phase,"-",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS3_phase - port1_MOS1_phase,"-",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS4_phase - port1_MOS1_phase,"-",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS5_phase - port1_MOS1_phase,"-",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS6_phase - port1_MOS1_phase,"-",color="purple")


plt.plot(port1_MOS1.f/1e9,port1_MOS6_phase - port2_MOS1_phase,"--",color="red")
plt.plot(port1_MOS1.f/1e9,port2_MOS1_phase - port2_MOS1_phase,"--",color="orange")
plt.plot(port1_MOS1.f/1e9,port3_MOS2_phase - port2_MOS1_phase,"--",color="yellow")
plt.plot(port1_MOS1.f/1e9,port4_MOS3_phase - port2_MOS1_phase,"--",color="green")
plt.plot(port1_MOS1.f/1e9,port5_MOS4_phase - port2_MOS1_phase,"--",color="blue")
plt.plot(port1_MOS1.f/1e9,port6_MOS5_phase - port2_MOS1_phase,"--",color="purple")


plt.grid()
plt.xlabel('Frequency [GHz]')
plt.ylabel('$S_{11}$ Phase difference From Flat Short [deg]')
plt.xlim((0,20))
#plt.ylim((-220,10))
plt.legend(['Port 1 A','Port 2 A','Port 3 A','Port 4 A','Port 5 A','Port 6 A','Port 1 B','Port 2 B','Port 3 B','Port 4 B','Port 5 B','Port 6 B'],loc=3)
