# %%
# load the needed libraries
import matplotlib.pyplot as plt
import numpy as np
import skrf as rf # if this doesn't work, do pip install scikit-rf

# %% [markdown]
# # Tier 2 Cal of all data sets in 6x6cal

# %%
# Load all tier 1 data, saved from tier 1 notebook, from 4 different folders:
tier1_3k1 = rf.read_all('tier1_scikitrf_caldata/tier1_3k1')
tier1_3k2 = rf.read_all('tier1_scikitrf_caldata/tier1_3k2')
tier1_295k1 = rf.read_all('tier1_scikitrf_caldata/tier1_295k1')
tier1_295k2 = rf.read_all('tier1_scikitrf_caldata/tier1_295k2')

# %%
# read in data extracted from MUF for calculated values of s11 from Maury offset short, flat short, and open standards
MOS_standards_MUF  = rf.read_all('MOS_standards_MUF')
my_ideals_3k = [\
        MOS_standards_MUF['MOS1'],
        MOS_standards_MUF['MOS2_cold'],
        MOS_standards_MUF['MOS3_cold'],
        MOS_standards_MUF['MOS4_cold'],
        MOS_standards_MUF['MOS5_cold'],
        MOS_standards_MUF['MOS6_cold']
]
my_ideals_295k = [\
        MOS_standards_MUF['MOS1'],
        MOS_standards_MUF['MOS2_warm'],
        MOS_standards_MUF['MOS3_warm'],
        MOS_standards_MUF['MOS4_warm'],
        MOS_standards_MUF['MOS5_warm'],
        MOS_standards_MUF['MOS6_warm']
]

# %%
# define sets of measured standards on each port at each temperature on each cooldown from tier 1 data

my_measured_port1_3k1 = [\
        tier1_3k1['port1_MOS1_tier1'],
        tier1_3k1['port1_MOS2_tier1'],
        tier1_3k1['port1_MOS3_tier1'],
        tier1_3k1['port1_MOS4_tier1'],
        tier1_3k1['port1_MOS5_tier1'],
        tier1_3k1['port1_MOS6_tier1']
]
my_measured_port2_3k1 = [\
        tier1_3k1['port2_MOS1_tier1'],
        tier1_3k1['port2_MOS2_tier1'],
        tier1_3k1['port2_MOS3_tier1'],
        tier1_3k1['port2_MOS4_tier1'],
        tier1_3k1['port2_MOS5_tier1'],
        tier1_3k1['port2_MOS6_tier1']
]
my_measured_port3_3k1 = [\
        tier1_3k1['port3_MOS1_tier1'],
        tier1_3k1['port3_MOS2_tier1'],
        tier1_3k1['port3_MOS3_tier1'],
        tier1_3k1['port3_MOS4_tier1'],
        tier1_3k1['port3_MOS5_tier1'],
        tier1_3k1['port3_MOS6_tier1']
]
my_measured_port4_3k1 = [\
        tier1_3k1['port4_MOS1_tier1'],
        tier1_3k1['port4_MOS2_tier1'],
        tier1_3k1['port4_MOS3_tier1'],
        tier1_3k1['port4_MOS4_tier1'],
        tier1_3k1['port4_MOS5_tier1'],
        tier1_3k1['port4_MOS6_tier1']
]
my_measured_port5_3k1 = [\
        tier1_3k1['port5_MOS1_tier1'],
        tier1_3k1['port5_MOS2_tier1'],
        tier1_3k1['port5_MOS3_tier1'],
        tier1_3k1['port5_MOS4_tier1'],
        tier1_3k1['port5_MOS5_tier1'],
        tier1_3k1['port5_MOS6_tier1']
]
my_measured_port6_3k1 = [\
        tier1_3k1['port6_MOS1_tier1'],
        tier1_3k1['port6_MOS2_tier1'],
        tier1_3k1['port6_MOS3_tier1'],
        tier1_3k1['port6_MOS4_tier1'],
        tier1_3k1['port6_MOS5_tier1'],
        tier1_3k1['port6_MOS6_tier1']
]
my_measured_port1_3k2 = [\
        tier1_3k2['port1_MOS1_tier1'],
        tier1_3k2['port1_MOS2_tier1'],
        tier1_3k2['port1_MOS3_tier1'],
        tier1_3k2['port1_MOS4_tier1'],
        tier1_3k2['port1_MOS5_tier1'],
        tier1_3k2['port1_MOS6_tier1']
]
my_measured_port2_3k2 = [\
        tier1_3k2['port2_MOS1_tier1'],
        tier1_3k2['port2_MOS2_tier1'],
        tier1_3k2['port2_MOS3_tier1'],
        tier1_3k2['port2_MOS4_tier1'],
        tier1_3k2['port2_MOS5_tier1'],
        tier1_3k2['port2_MOS6_tier1']
]
my_measured_port3_3k2 = [\
        tier1_3k2['port3_MOS1_tier1'],
        tier1_3k2['port3_MOS2_tier1'],
        tier1_3k2['port3_MOS3_tier1'],
        tier1_3k2['port3_MOS4_tier1'],
        tier1_3k2['port3_MOS5_tier1'],
        tier1_3k2['port3_MOS6_tier1']
]
my_measured_port4_3k2 = [\
        tier1_3k2['port4_MOS1_tier1'],
        tier1_3k2['port4_MOS2_tier1'],
        tier1_3k2['port4_MOS3_tier1'],
        tier1_3k2['port4_MOS4_tier1'],
        tier1_3k2['port4_MOS5_tier1'],
        tier1_3k2['port4_MOS6_tier1']
]
my_measured_port5_3k2 = [\
        tier1_3k2['port5_MOS1_tier1'],
        tier1_3k2['port5_MOS2_tier1'],
        tier1_3k2['port5_MOS3_tier1'],
        tier1_3k2['port5_MOS4_tier1'],
        tier1_3k2['port5_MOS5_tier1'],
        tier1_3k2['port5_MOS6_tier1']
]
my_measured_port6_3k2 = [\
        tier1_3k2['port6_MOS1_tier1'],
        tier1_3k2['port6_MOS2_tier1'],
        tier1_3k2['port6_MOS3_tier1'],
        tier1_3k2['port6_MOS4_tier1'],
        tier1_3k2['port6_MOS5_tier1'],
        tier1_3k2['port6_MOS6_tier1']
]
my_measured_port1_295k1 = [\
        tier1_295k1['port1_MOS1_tier1'],
        tier1_295k1['port1_MOS2_tier1'],
        tier1_295k1['port1_MOS3_tier1'],
        tier1_295k1['port1_MOS4_tier1'],
        tier1_295k1['port1_MOS5_tier1'],
        tier1_295k1['port1_MOS6_tier1']
]
my_measured_port2_295k1 = [\
        tier1_295k1['port2_MOS1_tier1'],
        tier1_295k1['port2_MOS2_tier1'],
        tier1_295k1['port2_MOS3_tier1'],
        tier1_295k1['port2_MOS4_tier1'],
        tier1_295k1['port2_MOS5_tier1'],
        tier1_295k1['port2_MOS6_tier1']
]
my_measured_port3_295k1 = [\
        tier1_295k1['port3_MOS1_tier1'],
        tier1_295k1['port3_MOS2_tier1'],
        tier1_295k1['port3_MOS3_tier1'],
        tier1_295k1['port3_MOS4_tier1'],
        tier1_295k1['port3_MOS5_tier1'],
        tier1_295k1['port3_MOS6_tier1']
]
my_measured_port4_295k1 = [\
        tier1_295k1['port4_MOS1_tier1'],
        tier1_295k1['port4_MOS2_tier1'],
        tier1_295k1['port4_MOS3_tier1'],
        tier1_295k1['port4_MOS4_tier1'],
        tier1_295k1['port4_MOS5_tier1'],
        tier1_295k1['port4_MOS6_tier1']
]
my_measured_port5_295k1 = [\
        tier1_295k1['port5_MOS1_tier1'],
        tier1_295k1['port5_MOS2_tier1'],
        tier1_295k1['port5_MOS3_tier1'],
        tier1_295k1['port5_MOS4_tier1'],
        tier1_295k1['port5_MOS5_tier1'],
        tier1_295k1['port5_MOS6_tier1']
]
my_measured_port6_295k1 = [\
        tier1_295k1['port6_MOS1_tier1'],
        tier1_295k1['port6_MOS2_tier1'],
        tier1_295k1['port6_MOS3_tier1'],
        tier1_295k1['port6_MOS4_tier1'],
        tier1_295k1['port6_MOS5_tier1'],
        tier1_295k1['port6_MOS6_tier1']
]
my_measured_port1_295k2 = [\
        tier1_295k2['port1_MOS1_tier1'],
        tier1_295k2['port1_MOS2_tier1'],
        tier1_295k2['port1_MOS3_tier1'],
        tier1_295k2['port1_MOS4_tier1'],
        tier1_295k2['port1_MOS5_tier1'],
        tier1_295k2['port1_MOS6_tier1']
]
my_measured_port2_295k2 = [\
        tier1_295k2['port2_MOS1_tier1'],
        tier1_295k2['port2_MOS2_tier1'],
        tier1_295k2['port2_MOS3_tier1'],
        tier1_295k2['port2_MOS4_tier1'],
        tier1_295k2['port2_MOS5_tier1'],
        tier1_295k2['port2_MOS6_tier1']
]
my_measured_port3_295k2 = [\
        tier1_295k2['port3_MOS1_tier1'],
        tier1_295k2['port3_MOS2_tier1'],
        tier1_295k2['port3_MOS3_tier1'],
        tier1_295k2['port3_MOS4_tier1'],
        tier1_295k2['port3_MOS5_tier1'],
        tier1_295k2['port3_MOS6_tier1']
]
my_measured_port4_295k2 = [\
        tier1_295k2['port4_MOS1_tier1'],
        tier1_295k2['port4_MOS2_tier1'],
        tier1_295k2['port4_MOS3_tier1'],
        tier1_295k2['port4_MOS4_tier1'],
        tier1_295k2['port4_MOS5_tier1'],
        tier1_295k2['port4_MOS6_tier1']
]
my_measured_port5_295k2 = [\
        tier1_295k2['port5_MOS1_tier1'],
        tier1_295k2['port5_MOS2_tier1'],
        tier1_295k2['port5_MOS3_tier1'],
        tier1_295k2['port5_MOS4_tier1'],
        tier1_295k2['port5_MOS5_tier1'],
        tier1_295k2['port5_MOS6_tier1']
]
my_measured_port6_295k2 = [\
        tier1_295k2['port6_MOS1_tier1'],
        tier1_295k2['port6_MOS2_tier1'],
        tier1_295k2['port6_MOS3_tier1'],
        tier1_295k2['port6_MOS4_tier1'],
        tier1_295k2['port6_MOS5_tier1'],
        tier1_295k2['port6_MOS6_tier1']
]

# %%
# define calibrations for each port at each temperature on each cooldown (6x2x2 = 24 calibrations)

cal_port1_3k1 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port1_3k1,
        )
cal_port2_3k1 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port2_3k1,
        )
cal_port3_3k1 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port3_3k1,
        )
cal_port4_3k1 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port4_3k1,
        )
cal_port5_3k1 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port5_3k1,
        )
cal_port6_3k1 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port6_3k1,
        )
cal_port1_3k2 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port1_3k2,
        )
cal_port2_3k2 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port2_3k2,
        )
cal_port3_3k2 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port3_3k2,
        )
cal_port4_3k2 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port4_3k2,
        )
cal_port5_3k2 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port5_3k2,
        )
cal_port6_3k2 = rf.OnePort(\
        ideals = my_ideals_3k,
        measured = my_measured_port6_3k2,
        )

cal_port1_295k1 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port1_295k1,
        )
cal_port2_295k1 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port2_295k1,
        )
cal_port3_295k1 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port3_295k1,
        )
cal_port4_295k1 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port4_295k1,
        )
cal_port5_295k1 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port5_295k1,
        )
cal_port6_295k1 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port6_295k1,
        )
cal_port1_295k2 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port1_295k2,
        )
cal_port2_295k2 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port2_295k2,
        )
cal_port3_295k2 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port3_295k2,
        )
cal_port4_295k2 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port4_295k2,
        )
cal_port5_295k2 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port5_295k2,
        )
cal_port6_295k2 = rf.OnePort(\
        ideals = my_ideals_295k,
        measured = my_measured_port6_295k2,
        )
# Out:
# ...
#                     attempting to interpolate the ideal[0] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[1] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[2] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[3] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[4] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[5] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[0] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[1] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[2] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[3] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[4] Network ..
# Success
# ...
#                     attempting to interpolate the ideal[5] Network ..
# Success
# ...

# %%
# Run all the calibrations
cal_port1_3k1.run()
cal_port2_3k1.run()
cal_port3_3k1.run()
cal_port4_3k1.run()
cal_port5_3k1.run()
cal_port6_3k1.run()
cal_port1_3k2.run()
cal_port2_3k2.run()
cal_port3_3k2.run()
cal_port4_3k2.run()
cal_port5_3k2.run()
cal_port6_3k2.run()
cal_port1_295k1.run()
cal_port2_295k1.run()
cal_port3_295k1.run()
cal_port4_295k1.run()
cal_port5_295k1.run()
cal_port6_295k1.run()
cal_port1_295k2.run()
cal_port2_295k2.run()
cal_port3_295k2.run()
cal_port4_295k2.run()
cal_port5_295k2.run()
cal_port6_295k2.run()

# %%
# create ideal standards 
freq = tier1_3k1['port1_MOS1_tier1'].frequency
shorts = freq.f*0.0 - 1.0 + 0j
opens = freq.f*0.0 + 1.0 + 0j
loads = freq.f*0.0 + 0.0 + 0j
ideal_short = rf.Network(s=shorts, frequency=freq, z0=50)
ideal_open = rf.Network(s=opens, frequency=freq, z0=50)
ideal_load = rf.Network(s=loads, frequency=freq, z0=50)

# %%
# apply all tier 2 calibrations to the ideal short, open and load

port1_short_tier2_3k1 = cal_port1_3k1.apply_cal(ideal_short)
port1_open_tier2_3k1 = cal_port1_3k1.apply_cal(ideal_open)
port1_load_tier2_3k1 = cal_port1_3k1.apply_cal(ideal_load)
port2_short_tier2_3k1 = cal_port2_3k1.apply_cal(ideal_short)
port2_open_tier2_3k1 = cal_port2_3k1.apply_cal(ideal_open)
port2_load_tier2_3k1 = cal_port2_3k1.apply_cal(ideal_load)
port3_short_tier2_3k1 = cal_port3_3k1.apply_cal(ideal_short)
port3_open_tier2_3k1 = cal_port3_3k1.apply_cal(ideal_open)
port3_load_tier2_3k1 = cal_port3_3k1.apply_cal(ideal_load)
port4_short_tier2_3k1 = cal_port4_3k1.apply_cal(ideal_short)
port4_open_tier2_3k1 = cal_port4_3k1.apply_cal(ideal_open)
port4_load_tier2_3k1 = cal_port4_3k1.apply_cal(ideal_load)
port5_short_tier2_3k1 = cal_port5_3k1.apply_cal(ideal_short)
port5_open_tier2_3k1 = cal_port5_3k1.apply_cal(ideal_open)
port5_load_tier2_3k1 = cal_port5_3k1.apply_cal(ideal_load)
port6_short_tier2_3k1 = cal_port6_3k1.apply_cal(ideal_short)
port6_open_tier2_3k1 = cal_port6_3k1.apply_cal(ideal_open)
port6_load_tier2_3k1 = cal_port6_3k1.apply_cal(ideal_load)

port1_short_tier2_3k2 = cal_port1_3k2.apply_cal(ideal_short)
port1_open_tier2_3k2 = cal_port1_3k2.apply_cal(ideal_open)
port1_load_tier2_3k2 = cal_port1_3k2.apply_cal(ideal_load)
port2_short_tier2_3k2 = cal_port2_3k2.apply_cal(ideal_short)
port2_open_tier2_3k2 = cal_port2_3k2.apply_cal(ideal_open)
port2_load_tier2_3k2 = cal_port2_3k2.apply_cal(ideal_load)
port3_short_tier2_3k2 = cal_port3_3k2.apply_cal(ideal_short)
port3_open_tier2_3k2 = cal_port3_3k2.apply_cal(ideal_open)
port3_load_tier2_3k2 = cal_port3_3k2.apply_cal(ideal_load)
port4_short_tier2_3k2 = cal_port4_3k2.apply_cal(ideal_short)
port4_open_tier2_3k2 = cal_port4_3k2.apply_cal(ideal_open)
port4_load_tier2_3k2 = cal_port4_3k2.apply_cal(ideal_load)
port5_short_tier2_3k2 = cal_port5_3k2.apply_cal(ideal_short)
port5_open_tier2_3k2 = cal_port5_3k2.apply_cal(ideal_open)
port5_load_tier2_3k2 = cal_port5_3k2.apply_cal(ideal_load)
port6_short_tier2_3k2 = cal_port6_3k2.apply_cal(ideal_short)
port6_open_tier2_3k2 = cal_port6_3k2.apply_cal(ideal_open)
port6_load_tier2_3k2 = cal_port6_3k2.apply_cal(ideal_load)

port1_short_tier2_295k1 = cal_port1_295k1.apply_cal(ideal_short)
port1_open_tier2_295k1 = cal_port1_295k1.apply_cal(ideal_open)
port1_load_tier2_295k1 = cal_port1_295k1.apply_cal(ideal_load)
port2_short_tier2_295k1 = cal_port2_295k1.apply_cal(ideal_short)
port2_open_tier2_295k1 = cal_port2_295k1.apply_cal(ideal_open)
port2_load_tier2_295k1 = cal_port2_295k1.apply_cal(ideal_load)
port3_short_tier2_295k1 = cal_port3_295k1.apply_cal(ideal_short)
port3_open_tier2_295k1 = cal_port3_295k1.apply_cal(ideal_open)
port3_load_tier2_295k1 = cal_port3_295k1.apply_cal(ideal_load)
port4_short_tier2_295k1 = cal_port4_295k1.apply_cal(ideal_short)
port4_open_tier2_295k1 = cal_port4_295k1.apply_cal(ideal_open)
port4_load_tier2_295k1 = cal_port4_295k1.apply_cal(ideal_load)
port5_short_tier2_295k1 = cal_port5_295k1.apply_cal(ideal_short)
port5_open_tier2_295k1 = cal_port5_295k1.apply_cal(ideal_open)
port5_load_tier2_295k1 = cal_port5_295k1.apply_cal(ideal_load)
port6_short_tier2_295k1 = cal_port6_295k1.apply_cal(ideal_short)
port6_open_tier2_295k1 = cal_port6_295k1.apply_cal(ideal_open)
port6_load_tier2_295k1 = cal_port6_295k1.apply_cal(ideal_load)

port1_short_tier2_295k2 = cal_port1_295k2.apply_cal(ideal_short)
port1_open_tier2_295k2 = cal_port1_295k2.apply_cal(ideal_open)
port1_load_tier2_295k2 = cal_port1_295k2.apply_cal(ideal_load)
port2_short_tier2_295k2 = cal_port2_295k2.apply_cal(ideal_short)
port2_open_tier2_295k2 = cal_port2_295k2.apply_cal(ideal_open)
port2_load_tier2_295k2 = cal_port2_295k2.apply_cal(ideal_load)
port3_short_tier2_295k2 = cal_port3_295k2.apply_cal(ideal_short)
port3_open_tier2_295k2 = cal_port3_295k2.apply_cal(ideal_open)
port3_load_tier2_295k2 = cal_port3_295k2.apply_cal(ideal_load)
port4_short_tier2_295k2 = cal_port4_295k2.apply_cal(ideal_short)
port4_open_tier2_295k2 = cal_port4_295k2.apply_cal(ideal_open)
port4_load_tier2_295k2 = cal_port4_295k2.apply_cal(ideal_load)
port5_short_tier2_295k2 = cal_port5_295k2.apply_cal(ideal_short)
port5_open_tier2_295k2 = cal_port5_295k2.apply_cal(ideal_open)
port5_load_tier2_295k2 = cal_port5_295k2.apply_cal(ideal_load)
port6_short_tier2_295k2 = cal_port6_295k2.apply_cal(ideal_short)
port6_open_tier2_295k2 = cal_port6_295k2.apply_cal(ideal_open)
port6_load_tier2_295k2 = cal_port6_295k2.apply_cal(ideal_load)

# %%
# save all the tier 2 standards for short, open, and load on all 6 ports at both temperatures on both runs

port1_short_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port1_short_tier2.s1p")
port1_open_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port1_open_tier2.s1p")
port1_load_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port1_load_tier2.s1p")
port2_short_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port2_short_tier2.s1p")
port2_open_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port2_open_tier2.s1p")
port2_load_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port2_load_tier2.s1p")
port3_short_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port3_short_tier2.s1p")
port3_open_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port3_open_tier2.s1p")
port3_load_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port3_load_tier2.s1p")
port4_short_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port4_short_tier2.s1p")
port4_open_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port4_open_tier2.s1p")
port4_load_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port4_load_tier2.s1p")
port5_short_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port5_short_tier2.s1p")
port5_open_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port5_open_tier2.s1p")
port5_load_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port5_load_tier2.s1p")
port6_short_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port6_short_tier2.s1p")
port6_open_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port6_open_tier2.s1p")
port6_load_tier2_3k1.write_touchstone("tier2_scikitrf_caldata/tier2_3k1/port6_load_tier2.s1p")

port1_short_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port1_short_tier2.s1p")
port1_open_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port1_open_tier2.s1p")
port1_load_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port1_load_tier2.s1p")
port2_short_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port2_short_tier2.s1p")
port2_open_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port2_open_tier2.s1p")
port2_load_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port2_load_tier2.s1p")
port3_short_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port3_short_tier2.s1p")
port3_open_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port3_open_tier2.s1p")
port3_load_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port3_load_tier2.s1p")
port4_short_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port4_short_tier2.s1p")
port4_open_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port4_open_tier2.s1p")
port4_load_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port4_load_tier2.s1p")
port5_short_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port5_short_tier2.s1p")
port5_open_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port5_open_tier2.s1p")
port5_load_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port5_load_tier2.s1p")
port6_short_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port6_short_tier2.s1p")
port6_open_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port6_open_tier2.s1p")
port6_load_tier2_3k2.write_touchstone("tier2_scikitrf_caldata/tier2_3k2/port6_load_tier2.s1p")

port1_short_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port1_short_tier2.s1p")
port1_open_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port1_open_tier2.s1p")
port1_load_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port1_load_tier2.s1p")
port2_short_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port2_short_tier2.s1p")
port2_open_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port2_open_tier2.s1p")
port2_load_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port2_load_tier2.s1p")
port3_short_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port3_short_tier2.s1p")
port3_open_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port3_open_tier2.s1p")
port3_load_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port3_load_tier2.s1p")
port4_short_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port4_short_tier2.s1p")
port4_open_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port4_open_tier2.s1p")
port4_load_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port4_load_tier2.s1p")
port5_short_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port5_short_tier2.s1p")
port5_open_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port5_open_tier2.s1p")
port5_load_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port5_load_tier2.s1p")
port6_short_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port6_short_tier2.s1p")
port6_open_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port6_open_tier2.s1p")
port6_load_tier2_295k1.write_touchstone("tier2_scikitrf_caldata/tier2_295k1/port6_load_tier2.s1p")

port1_short_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port1_short_tier2.s1p")
port1_open_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port1_open_tier2.s1p")
port1_load_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port1_load_tier2.s1p")
port2_short_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port2_short_tier2.s1p")
port2_open_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port2_open_tier2.s1p")
port2_load_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port2_load_tier2.s1p")
port3_short_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port3_short_tier2.s1p")
port3_open_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port3_open_tier2.s1p")
port3_load_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port3_load_tier2.s1p")
port4_short_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port4_short_tier2.s1p")
port4_open_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port4_open_tier2.s1p")
port4_load_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port4_load_tier2.s1p")
port5_short_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port5_short_tier2.s1p")
port5_open_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port5_open_tier2.s1p")
port5_load_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port5_load_tier2.s1p")
port6_short_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port6_short_tier2.s1p")
port6_open_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port6_open_tier2.s1p")
port6_load_tier2_295k2.write_touchstone("tier2_scikitrf_caldata/tier2_295k2/port6_load_tier2.s1p")
